# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler

# %%
data=pd.read_csv("/content/drive/MyDrive/dataset/fake_job_-_fake_job_postings_(1)_(1)_(1).csv")
data
# Out:
#      job_id                                           title  \
# 0         1                                Marketing Intern
# 1         2       Customer Service - Cloud Video Production
# 2         3         Commissioning Machinery Assistant (CMA)
# 3         4               Account Executive - Washington DC
# 4         5                             Bill Review Manager
# ..      ...                                             ...
# 515     516                                 Visual Designer
# 516     517                                   Brand Partner
# 517     518                                 Web UI Engineer
# 518     519                      Dairy & Farming Consultant
# 519     520  Reading Fragrance and Beauty Promotional Staff
#
#                location   department salary_range  \
# 0      US, NY, New York    Marketing          NaN
# 1        NZ, , Auckland      Success          NaN
# 2         US, IA, Wever          NaN          NaN
# 3    US, DC, Washington        Sales          NaN
# 4    US, FL, Fort Worth          NaN          NaN
# ..                  ...          ...          ...
# 515  US, PA, Pittsburgh      Product          NaN
# 516           GB, LND,            BD          NaN
# 517    GB, , Birmingham          NaN          NaN
# 518     US, AZ, Phoenix  Agriculture          NaN
# 519       GB, , Reading          NaN          NaN
#
#                                        company_profile  \
# 0    We're Food52, and we've created a groundbreaki...
# 1    90 Seconds, the worlds Cloud Video Production ...
# 2    Valor Services provides Workforce Solutions th...
# 3    Our passion for improving quality of life thro...
# 4    SpotSource Solutions LLC is a Global Human Cap...
# ..                                                 ...
# 515  Everyone has a story to tell. Everyone is uniq...
# 516  As augmented reality jobs go, one at Blippar i...
# 517  Friend MTS is a leading provider of technology...
# 518                                                NaN
# 519  Established on the principles that full time e...
#
#                                            description  \
# 0    Food52, a fast-growing, James Beard Award-winn...
# 1    Organised - Focused - Vibrant - Awesome!Do you...
# 2    Our client, located in Houston, is actively se...
# 3    THE COMPANY: ESRI – Environmental Systems Rese...
# 4    JOB TITLE: Itemization Review ManagerLOCATION:...
# ..                                                 ...
# 515  Closely work with other members of the product...
# 516  Do you have an unquenchable entrepreneurial th...
# 517  The RoleWe are recruiting for a talented Web U...
# 518  Looking for a Consultant with experience in wo...
# 519  We are currently recruiting for an exciting Sa...
#
#                                           requirements  \
# 0    Experience with content management systems a m...
# 1    What we expect from you:Your key responsibilit...
# 2    Implement pre-commissioning and commissioning ...
# 3    EDUCATION: Bachelor’s or Master’s in GIS, busi...
# 4    QUALIFICATIONS:RN license in the State of Texa...
# ..                                                 ...
# 515  Required ExperienceMinimum 1 year of experienc...
# 516  4+ years relevant work experience in digital, ...
# 517  Very good understanding and experience of UI d...
# 518                                                NaN
# 519                 Experience in fragrance and sales.
#
#                                               benefits  telecommuting  \
# 0                                                  NaN              0
# 1    What you will get from usThrough being part of...              0
# 2                                                  NaN              0
# 3    Our culture is anything but corporate—we have ...              0
# 4                                Full Benefits Offered              0
# ..                                                 ...            ...
# 515  Competitive salary commensurate with skills an...              0
# 516  Our bright, open, centrally located offices ar...              0
# 517  An understanding of concepts such as MVC or ot...              0
# 518                                                NaN              0
# 519                             Bonuses are available.              0
#
#      has_company_logo  has_questions employment_type required_experience  \
# 0                   1              0           Other          Internship
# 1                   1              0       Full-time      Not Applicable
# 2                   1              0             NaN                 NaN
# 3                   1              0       Full-time    Mid-Senior level
# 4                   1              1       Full-time    Mid-Senior level
# ..                ...            ...             ...                 ...
# 515                 1              1       Full-time           Associate
# 516                 1              0             NaN                 NaN
# 517                 1              0       Full-time                 NaN
# 518                 0              0             NaN                 NaN
# 519                 1              1       Temporary           Associate
#
#     required_education                             industry  \
# 0                  NaN                                  NaN
# 1                  NaN            Marketing and Advertising
# 2                  NaN                                  NaN
# 3    Bachelor's Degree                    Computer Software
# 4    Bachelor's Degree               Hospital & Health Care
# ..                 ...                                  ...
# 515   Associate Degree                             Internet
# 516                NaN                                  NaN
# 517                NaN  Information Technology and Services
# 518                NaN                                  NaN
# 519        Unspecified                            Cosmetics
#
#                  function  fraudulent
# 0               Marketing           0
# 1        Customer Service           0
# 2                     NaN           0
# 3                   Sales           0
# 4    Health Care Provider           0
# ..                    ...         ...
# 515                Design           0
# 516                   NaN           0
# 517           Engineering           0
# 518                   NaN           0
# 519                 Sales           0
#
# [520 rows x 18 columns]

# %%
data.drop(['job_id'],axis=1,inplace=True)

# %%
data[['salary_range']]
# Out:
#     salary_range
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 515          NaN
# 516          NaN
# 517          NaN
# 518          NaN
# 519          NaN
#
# [520 rows x 1 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                520 non-null    object
#  1   location             510 non-null    object
#  2   department           157 non-null    object
#  3   salary_range         84 non-null     object
#  4   company_profile      447 non-null    object
#  5   description          520 non-null    object
#  6   requirements         458 non-null    object
#  7   benefits             303 non-null    object
#  8   telecommuting        520 non-null    int64
#  9   has_company_logo     520 non-null    int64
#  10  has_questions        520 non-null    int64
#  11  employment_type      440 non-null    object
#  12  required_experience  324 non-null    object
#  13  required_education   349 non-null    object
#  14  industry             406 non-null    object
#  15  function             336 non-null    object
#  16  fraudulent           520 non-null    int64
# dtypes: int64(4), object(13)
# memory usage: 69.2+ KB

# %%
data['salary_range'].unique()
# Out:
# array([nan, '20000-28000', '100000-120000', '120000-150000',
#        '50000-65000', '40000-50000', '60-80', '65000-70000', '75-115',
#        '75000-110000', '17000-20000', '16000-28000', '95000-115000',
#        '15000-18000', '50000-70000', '45000-60000', '30000-40000',
#        '70000-90000', '10000-14000', '50-110', '28000-45000', '0-34300',
#        '35000-40000', '9-Dec', '44000-57000', '18500-28000',
#        '55000-75000', '30000-35000', '0-0', '20000-40000',
#        '360000-600000', '50000-80000', '80000-100000', '52000-78000',
#        '15750-15750', '40000-65000', '45000-50000', '30000-37000',
#        '45000-67000', '35000-100000', '180000-216000', '45000-65000',
#        '28000-32000', '0-1000', '36000-40000', '80000-110000',
#        '35000-73000', '19000-19000', '60000-120000', '120000-15000000',
#        '42000-55000', '90000-120000', '100000-150000', '28000-38000',
#        '1600-1700', '50000-60000', '30000-70000', '32000-40000', '50-100',
#        '9000-17000', '23040-28800', '105-110'], dtype=object)

# %%
salary_list=[np.nan, '20000-28000', '100000-120000', '120000-150000',
       '50000-65000', '40000-50000', '60-80', '65000-70000', '75-115',
       '75000-110000', '17000-20000', '16000-28000', '95000-115000',
       '15000-18000', '50000-70000', '45000-60000', '30000-40000',
       '70000-90000', '10000-14000', '50-110', '28000-45000', '0-34300',
       '35000-40000', '9-Dec', '44000-57000', '18500-28000',
       '55000-75000', '30000-35000', '0-0', '20000-40000',
       '360000-600000', '50000-80000', '80000-100000', '52000-78000',
       '15750-15750', '40000-65000', '45000-50000', '30000-37000',
       '45000-67000', '35000-100000', '180000-216000', '45000-65000',
       '28000-32000', '0-1000', '36000-40000', '80000-110000',
       '35000-73000', '19000-19000', '60000-120000', '120000-15000000',
       '42000-55000', '90000-120000', '100000-150000', '28000-38000',
       '1600-1700', '50000-60000', '30000-70000', '32000-40000', '50-100',
       '9000-17000', '23040-28800', '105-110']

# %%
salary_mean=[32500,(20000+28000)/2,(100000+120000)/2,(120000+150000)/2,57500,45000,70,67500,95,92500,18500,22000,
             105000,16500,60000,52500,35000,80000,12000,80,36500,17150,37500,10,50500,(18500+28000)/2,65000,32500,0,30000,
             480000,65000,90000,65000,15750,52500,47500,33500,56000,67500,(18000+216000)/2,55000,30000,500,38000,95000,(35000+73000)/2,19000,90000,(120000+15000000)/2,
             48500,105000,125000,33000,1650,55000,50000,36000,75,13000,(23040+28800)/2,107.5]

# %%
data['salary_range']=data['salary_range'].replace(salary_list,salary_mean)

# %%
data['salary_range'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 515    False
# 516    False
# 517    False
# 518    False
# 519    False
# Name: salary_range, Length: 520, dtype: bool

# %%
data1=data.copy()

# %%
data1['salary_range'].dtypes
# Out:
# dtype('float64')

# %%
data1[['location']]
# Out:
#                location
# 0      US, NY, New York
# 1        NZ, , Auckland
# 2         US, IA, Wever
# 3    US, DC, Washington
# 4    US, FL, Fort Worth
# ..                  ...
# 515  US, PA, Pittsburgh
# 516           GB, LND,
# 517    GB, , Birmingham
# 518     US, AZ, Phoenix
# 519       GB, , Reading
#
# [520 rows x 1 columns]

# %%
data1['location'].unique()
# Out:
# array(['US, NY, New York', 'NZ, , Auckland', 'US, IA, Wever',
#        'US, DC, Washington', 'US, FL, Fort Worth', 'US, MD, ',
#        'DE, BE, Berlin', 'US, CA, San Francisco', 'US, FL, Pensacola',
#        'US, AZ, Phoenix', 'US, NJ, Jersey City', 'GB, LND, London',
#        'US, CT, Stamford', 'US, FL, Orlando', 'AU, NSW, Sydney',
#        'SG, 01, Singapore', 'IL, , Tel Aviv, Israel',
#        'GB, SOS, Southend-on-Sea', 'US, PA, USA Northeast',
#        'US, TX, Austin', 'NZ, N, Auckland', 'AE, , ', 'US, CA, Carlsbad',
#        'US, NY, New York ', 'SG, , ', 'AE, AZ, Abudhabi',
#        'US, MO, St. Louis', 'CA, ON, Toronto', 'US, MA, Waltham',
#        'US, KS, ', 'US, WA, Everett', 'US, CA, San Ramon', 'GB, LND, ',
#        'US, NY, Saint Bonaventure', 'US, NY, Yonkers', 'US, TX, HOUSTON',
#        'IN, AP, Hyderabad', 'US, IL, Chicago', 'US, PA, Kutztown',
#        'US, CA, Sacramento', 'US', 'US, MD, Columbia', 'US, OK, Tulsa',
#        'US, NE, Omaha', 'EG, C, ', 'US, TN, Brentwood', 'US, OH, Kent',
#        'US, NH, Dover', 'US, NV, Carson City', 'US, NY, New York City',
#        'US, MN, St. Cloud', 'PL, , ', 'US, MN, Oronoco', 'CA, ON, Ottawa',
#        'US, TX, Fort Worth', 'US, IA, Iowa city', 'US, IA, Cedar Rapids',
#        'US, CT, Windsor', 'US, , ', 'GR, I, Athens',
#        'US, PA, Philadelphia', 'US, OH, Cincinnati',
#        'US, CA, Menlo Park, CA', 'US, NY, Otisville',
#        'US, FL, Plantation', 'AE, DU, Dubai', 'US, GA, Atlanta',
#        'US, PA, Scranton', 'NZ, N, Wel', 'US, CA, Anaheim',
#        'GB, , Edinburgh', 'US, KY, London', 'US, NC, Charlotte',
#        'US, CA, Newport Beach', 'US, MN, Minneapolis', 'US, TN, Franklin',
#        'CA, ON,  Ottawa', 'GB, , ', 'US, SC, Columbia', 'GB, , Birstall',
#        'GB, , London', 'US, PA, Pittsburgh', 'US, , Stocton, CA',
#        'US, NC, Raleigh', 'CA, MB, Winnipeg', 'GB, WAR, Coventry',
#        'US, PA, Reading', 'US, FL, Jacksonville', 'GB, , Gatwick',
#        'US, TX, Dallas', 'US, IN, Indianapolis', 'US, OR, Portland',
#        'GB, WLV, Kingswinford', 'US, CA, Los Angeles',
#        'GB, BIR, Birmingham', 'US, IL, Melrose Park', 'US, MA, Amherst',
#        'DE, BY, Wiepoldsried', 'CA, ON, Brampton', 'US, CO, Fort Collins',
#        'US, FL, Boca Raton', 'US, NY, Brooklyn', 'US, GA, ',
#        'US, IA, Harlan or Ames', 'US, NH, Bedford', 'GB, , Milton Keynes',
#        'GB, MAN, Wigan', 'US, NV, Reno', 'GB, , Manchester',
#        'US, NC, Fayetteville', 'DE, , Berlin', 'US, CA, Palo Alto',
#        'IL, TA, Tel Aviv', 'US, TX, Hidalgo', nan, 'US, MA, Haverhill',
#        'US, NJ, Piscataway', 'US, VA, Richmond', 'US, AL, Jacksonville',
#        'US, CT, Hartford', 'US, WI, Western Wisconsin ',
#        'US, MI, Detroit', 'EG, C, Cairo', 'US, MD, Baltimore',
#        'US, SD, Rapid City', 'GB, CMD, London', 'AU, QLD, Brisbane',
#        'US, , Newcastle', 'US, VA, Virginia Beach', 'US, UT, Draper',
#        'PK, SD, Karachi', 'US, CA, Moreno Valley', 'US, TX, Houston',
#        'US, , Oshkosh', 'GB, RDG, ', 'US, OH, Columbia', 'US, AR, Conway',
#        'US, AR, Little Rock', 'US, CT, Wallingford', 'GR, I, Maroussi',
#        'GR, E, Volos', 'US, NY, Ithaca', 'IN, MP, Indore',
#        'GB, MAN, Manchester', 'US, IL, Springfield', 'BE, , Brussels',
#        'US, OH, Tiffin', 'US, CA, San Mateo', 'US, ME, South Portland',
#        'US, FL, Lake Mary', 'BR, RJ, Rio De Janeiro', 'CA, AB, Edmonton',
#        'US, CA, Inglewood', 'US, CA, Bakersfield, CA / Mt. Poso',
#        'US, MT, Bozeman', 'SA, 01, Riyadh, Olaya', 'GB, DNC, Doncaster',
#        'DK, , Copenhagen', 'US, CA, Irvine', 'US, CA, Claremont',
#        'GB, LIN, grimsby', 'US, MA, Cambridge', 'US, IL, Carbondale',
#        'GB, LDS, Elland', 'GB, , Ossett', 'US, DC, washington',
#        'US, AZ, Mesa', 'RU, MOW, Moscow', 'US, TX, Plano', 'GB, SOM, ',
#        'ZA, EC, East London', 'US, IL, Schaumburg', 'GB, GBN, London',
#        'US, CA, Isla Vista', 'US, MA, Boston', 'US, PA, State College',
#        'US, FL, Tampa', 'US, VA, Sterling', 'US, CO, Denver',
#        'GB, ESS, Chelmsford', 'US, CT, Danbury',
#        'GB, , Huddersfield/Wakefield', 'US, NC, Raliegh',
#        'US, CA, West Hollywood', 'GR, , ',
#        'US, NJ, Newark\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#        'US, IL, Evanston', 'CY, 01, ', 'US, CA, Burbank',
#        'US, FL, Tallahassee', "US, MO, St. Peter's", 'US, PA, Indiana',
#        'US, MO, Cape Girardo', 'US, AL, Troy', 'US, NV, Las Vegas',
#        'GB, ENG, London', 'US, TX, McAllen', 'US, OH, Fairfield',
#        'US, OK, Oklahoma CIty', 'US, MI, East Lansing', 'DE, BY, Munich',
#        'HK, , ', 'US, TX, Lubbock', 'EG, C, Cairo, Nasr City',
#        'US, GA, Duluth ', 'IN, , ', 'GB, WSM, London',
#        'AU, NSW, Surry Hills', 'US, SC, Charleston', 'US, VA, Reston',
#        'US, IA, Dubuque', 'US, MO, Kirksville', 'TR, 34, Istanbul',
#        'US, NY, NY', 'BE, BRU, Brussels', 'US, AR, Jonesboro', 'US, NY, ',
#        'US, TX, ', 'GR, I, Neo Iraklio, Athens', 'CA, NT, Yellowknife',
#        'US, MI, Kalamazoo', 'DE, , Germany', 'US, FL, Orlando ',
#        'IE, L, Dublin', 'US, MN, St Paul', 'US, CT, Norwalk',
#        'US, IL, hazelcrest', 'US, PA, Warrington', 'US, NC, Elon',
#        'GB, , Southport', 'US, CA, Atherton', 'US, IN, Fishers',
#        'US, CA, Newport Beach ', 'US, TX, Frisco', 'US, MN, Burnsville',
#        'US, OR, Eugene', 'CA, BC, Vancouver', 'US, CA, San Diego',
#        'US, OH, Athens', 'AU, VIC, Melbourne', 'IN, MP, indore',
#        'DE, BE, ', 'CA, QC, Montreal', 'US, WA, Redmond',
#        'US, WA, Seattle', 'LT, VL, Vilnius', 'JP, 13, Shibuya',
#        'DE, BY, München', 'US, CA, Burlingame', 'US, IN, Greencastle',
#        'US, NJ, East Hanover', 'US, OK, Bethany', 'US, NY, NYC',
#        'US, NJ, Somerville', 'NL, , Amsterdam', 'US, TN, Spring Hill',
#        'IN, MH, mumbai', 'US, IL, Gurnee', 'US, CT, Bloomfield',
#        'US, MA, PITTSFIELD', 'US, CA, Riverside', 'US, MA, Wilmington',
#        'GB, UKM, Stockholm, Sweden', 'US, NC, Lexington',
#        'US, GA, Athens', 'AT, 5, ', 'US, CA, Redlands', 'GB, HCK, London',
#        'AU, , ', 'PL, , Warsaw', 'US, NY, Albany', 'US, CA, San Carlos',
#        'US, CA, San Jose', 'KR, , Seoul', 'US, WI, Wausau',
#        'GB, ISL, London', 'FR, U, Aix en Provence', 'US, VA, Manassas',
#        'US, OH, Dublin', 'US, IL, Crete', 'US, NY, Niagara Falls',
#        'US, TX, Corpus Christi', 'US, WI, Milwaukee', 'GR, M, Heraklion',
#        'US, IL, Warrenville', 'US, TX, Tyler', 'GB, , Skipton',
#        'US, OH, Seven Hills', 'GR, I, ATHENS', 'ZA, , ', 'BR, , ',
#        'US, CO, Englewood', 'US, MI, Macomb', 'US, MI, Ann Arbor',
#        'US, DE, Wilmington', 'US, VA, Vienna', 'US, MN, Savage',
#        'US, UT, Logan', 'GB, SHF, ', 'GB, , Birmingham', 'GB, , Reading'],
#       dtype=object)

# %%
state_list=['Kerala','Tamilnadu','Karnataka','Telangana','Andhra','Goa','Maharashtra','Madhyapradesh','Gujarat','Rajasthan','Punjab','Bihar','Uttarpradesh','Assam','Manipur','ArunachalPradesh','WestBengal','Mizoram','Orissa','Chattisgarh']

# %%
data1['location']=np.nan

# %%
data1['location']=data1['location'].fillna(pd.Series(np.random.choice(state_list, size=len(data1.index))))

# %%
data1['location'].unique()
# Out:
# array(['ArunachalPradesh', 'Bihar', 'Assam', 'Gujarat', 'Chattisgarh',
#        'Karnataka', 'WestBengal', 'Telangana', 'Uttarpradesh', 'Kerala',
#        'Madhyapradesh', 'Goa', 'Tamilnadu', 'Mizoram', 'Rajasthan',
#        'Maharashtra', 'Manipur', 'Orissa', 'Punjab', 'Andhra'],
#       dtype=object)

# %%
data1[['location']]
# Out:
#              location
# 0    ArunachalPradesh
# 1               Bihar
# 2               Assam
# 3             Gujarat
# 4         Chattisgarh
# ..                ...
# 515            Andhra
# 516           Manipur
# 517        WestBengal
# 518        WestBengal
# 519            Andhra
#
# [520 rows x 1 columns]

# %%
data1['department']=np.nan

# %%
company_list=['ANDROIDPIT','Sales','Oil & Energy','Marketplace','Sales and Business Developement','Production','Playfair Capital',
              'Software developement','Business Developement','Financial']

# %%
data1['department']=data1['department'].fillna(pd.Series(np.random.choice(company_list,size=len(data1.index))))

# %%
data1['department'].unique()
# Out:
# array(['Production', 'Business Developement', 'Playfair Capital',
#        'Software developement', 'Oil & Energy',
#        'Sales and Business Developement', 'Sales', 'Financial',
#        'ANDROIDPIT', 'Marketplace'], dtype=object)

# %%
data1['company_profile']=data1['company_profile'].isnull().sum()

# %%
data1.columns
# Out:
# Index(['title', 'location', 'department', 'salary_range', 'company_profile',
#        'description', 'requirements', 'benefits', 'telecommuting',
#        'has_company_logo', 'has_questions', 'employment_type',
#        'required_experience', 'required_education', 'industry', 'function',
#        'fraudulent'],
#       dtype='object')

# %%
data1['company_profile']=np.nan
data1['description']=np.nan
data1['requirements']=np.nan
data1['benefits']=np.nan
data1['employment_type']=np.nan

# %%
cols=['company_profile','description','requirements','benefits','employment_type']

# %%
for col in cols:
  data1[col]=data1[col].fillna(pd.Series(np.random.choice(['Yes','No'],size=len(data1.index))))

# %%
data1.isnull().sum()
# Out:
# title                    0
# location                 0
# department               0
# salary_range             0
# company_profile          0
# description              0
# requirements             0
# benefits                 0
# telecommuting            0
# has_company_logo         0
# has_questions            0
# employment_type          0
# required_experience    196
# required_education     171
# industry               114
# function               184
# fraudulent               0
# dtype: int64

# %%
data1['employment_type'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data1['employment_type']=data1['employment_type'].fillna(pd.Series(np.random.choice(['Other','Full-Time','Part-Time','Contract','Temporary'],size=len(data1.index))))

# %%
data1.isnull().sum()
# Out:
# title                    0
# location                 0
# department               0
# salary_range             0
# company_profile          0
# description              0
# requirements             0
# benefits                 0
# telecommuting            0
# has_company_logo         0
# has_questions            0
# employment_type          0
# required_experience    196
# required_education     171
# industry               114
# function               184
# fraudulent               0
# dtype: int64

# %%
data1['function'].unique()
# Out:
# array(['Marketing', 'Customer Service', nan, 'Sales',
#        'Health Care Provider', 'Management', 'Information Technology',
#        'Other', 'Engineering', 'Administrative', 'Design', 'Production',
#        'Education', 'Supply Chain', 'Business Development',
#        'Product Management', 'Financial Analyst', 'Consulting',
#        'Human Resources', 'Project Management', 'Manufacturing',
#        'Public Relations', 'Strategy/Planning', 'Advertising', 'Finance',
#        'General Business', 'Research', 'Accounting/Auditing',
#        'Art/Creative', 'Quality Assurance', 'Data Analyst',
#        'Business Analyst', 'Writing/Editing'], dtype=object)

# %%
function_list=['Marketing','Customer Service','sales','Health Care Provider','Management','Information Technology','Engineering',
               'Administrative','Design','Production','Supply Chain']

experience_list=['Internship','Not Applicable','Mid-Senior level','Associate','Entry level','Executive','Director']

# %%
education_list=["Bachelor's degree","master's degree",'Highschool or equivalant','Unspecified','Some College Coursework Completed','Vocational',
                'Certification','Associate Degree','Professional','Doctorate']
industry_list=['Marketing and Advertising','Computer Software','Hospital and Health Care','Online Media','Information Technology and Services',
               'Financial Services','Management Counsulting','Events Services','Internet','facilities services','Consumer Electronics','Telecommunications',
               'Consumer Services','Construction','Oil & Enenrgy','Education management']  
employment_list=['Other','Full-Time','Part-Time','Contract','Temporary']
title_list=['Marketing Intern','Bill review manager','Accounting Clerk','Lead guest Service Specialist','Application Developer','visual Designer',
            'Talent Management Process Manager','Software Application Specialist','Project manager','Junior HR Marketing manager','BI Developer']

# %%
column1=['title','function','experience','industry','employment_type','required_education','required_experience']
for col in column1:
  data1[col]=np.nan

# %%
data1.isnull().sum()
# Out:
# title                  520
# location                 0
# department               0
# salary_range             0
# company_profile          0
# description              0
# requirements             0
# benefits                 0
# telecommuting            0
# has_company_logo         0
# has_questions            0
# employment_type        520
# required_experience    520
# required_education     520
# industry               520
# function               520
# fraudulent               0
# experience             520
# dtype: int64

# %%
data1['title']=data1['title'].fillna(pd.Series(np.random.choice(title_list,size=len(data1.index))))
data1['function']=data1['function'].fillna(pd.Series(np.random.choice(function_list,size=len(data1.index))))
data1['experience']=data1['experience'].fillna(pd.Series(np.random.choice(experience_list,size=len(data1.index))))
data1['industry']=data1['industry'].fillna(pd.Series(np.random.choice(industry_list,size=len(data1.index))))
data1['employment_type']=data1['employment_type'].fillna(pd.Series(np.random.choice(employment_list,size=len(data1.index))))
data1['required_education']=data1['required_education'].fillna(pd.Series(np.random.choice(education_list,size=len(data1.index))))
data1['required_experience']=data1['required_experience'].fillna(pd.Series(np.random.choice(experience_list,size=len(data1.index))))

# %%
data1['required_experience'].unique()
# Out:
# array(['Not Applicable', 'Mid-Senior level', 'Director', 'Internship',
#        'Entry level', 'Executive', 'Associate'], dtype=object)

# %%
data1['required_education'].unique()
# Out:
# array(['Some College Coursework Completed', "Bachelor's degree",
#        'Vocational', 'Associate Degree', "master's degree", 'Unspecified',
#        'Doctorate', 'Professional', 'Highschool or equivalant',
#        'Certification'], dtype=object)

# %%
data1['industry'].unique()
# Out:
# array(['Consumer Services', 'Telecommunications', 'Events Services',
#        'Internet', 'Education management', 'Management Counsulting',
#        'Information Technology and Services', 'Consumer Electronics',
#        'Hospital and Health Care', 'Computer Software', 'Oil & Enenrgy',
#        'Online Media', 'Financial Services', 'Construction',
#        'Marketing and Advertising', 'facilities services'], dtype=object)

# %%
data1.drop(['experience'],axis='columns',inplace=True)

# %%
data1
# Out:
#                                  title          location  \
# 0                  Bill review manager  ArunachalPradesh
# 1                     Marketing Intern             Bihar
# 2        Lead guest Service Specialist             Assam
# 3                      Project manager           Gujarat
# 4          Junior HR Marketing manager       Chattisgarh
# ..                                 ...               ...
# 515                   Marketing Intern            Andhra
# 516                    Project manager           Manipur
# 517  Talent Management Process Manager        WestBengal
# 518                    visual Designer        WestBengal
# 519                   Marketing Intern            Andhra
#
#                 department  salary_range company_profile description  \
# 0               Production       32500.0             Yes          No
# 1    Business Developement       32500.0             Yes         Yes
# 2         Playfair Capital       32500.0             Yes         Yes
# 3         Playfair Capital       32500.0             Yes         Yes
# 4    Software developement       32500.0              No          No
# ..                     ...           ...             ...         ...
# 515             ANDROIDPIT       32500.0              No          No
# 516             Production       32500.0             Yes          No
# 517                  Sales       32500.0              No          No
# 518  Software developement       32500.0             Yes         Yes
# 519                  Sales       32500.0              No          No
#
#     requirements benefits  telecommuting  has_company_logo  has_questions  \
# 0            Yes       No              0                 1              0
# 1             No       No              0                 1              0
# 2             No       No              0                 1              0
# 3            Yes       No              0                 1              0
# 4             No      Yes              0                 1              1
# ..           ...      ...            ...               ...            ...
# 515           No      Yes              0                 1              1
# 516          Yes      Yes              0                 1              0
# 517           No      Yes              0                 1              0
# 518           No      Yes              0                 0              0
# 519           No      Yes              0                 1              1
#
#     employment_type required_experience                 required_education  \
# 0             Other      Not Applicable  Some College Coursework Completed
# 1         Part-Time    Mid-Senior level                  Bachelor's degree
# 2         Full-Time      Not Applicable                         Vocational
# 3         Full-Time            Director                   Associate Degree
# 4         Part-Time    Mid-Senior level                    master's degree
# ..              ...                 ...                                ...
# 515       Temporary      Not Applicable                      Certification
# 516       Temporary      Not Applicable                   Associate Degree
# 517       Part-Time           Executive                      Certification
# 518       Full-Time          Internship                   Associate Degree
# 519       Temporary    Mid-Senior level           Highschool or equivalant
#
#                       industry                function  fraudulent
# 0            Consumer Services        Customer Service           0
# 1           Telecommunications          Administrative           0
# 2            Consumer Services    Health Care Provider           0
# 3              Events Services  Information Technology           0
# 4                     Internet                   sales           0
# ..                         ...                     ...         ...
# 515              Oil & Enenrgy              Management           0
# 516       Education management              Management           0
# 517                   Internet              Production           0
# 518  Marketing and Advertising              Management           0
# 519          Consumer Services              Production           0
#
# [520 rows x 17 columns]

# %%
data1[7:35]
# Out:
#                                 title          location  \
# 7       Lead guest Service Specialist        WestBengal
# 8                     Project manager             Assam
# 9     Software Application Specialist       Chattisgarh
# 10      Lead guest Service Specialist         Telangana
# 11                Bill review manager       Chattisgarh
# 12                    visual Designer      Uttarpradesh
# 13    Software Application Specialist            Kerala
# 14                       BI Developer     Madhyapradesh
# 15  Talent Management Process Manager             Bihar
# 16                   Accounting Clerk               Goa
# 17      Lead guest Service Specialist         Tamilnadu
# 18    Software Application Specialist           Mizoram
# 19    Software Application Specialist      Uttarpradesh
# 20  Talent Management Process Manager             Assam
# 21      Lead guest Service Specialist  ArunachalPradesh
# 22      Lead guest Service Specialist        WestBengal
# 23    Software Application Specialist         Rajasthan
# 24      Lead guest Service Specialist         Telangana
# 25    Software Application Specialist             Bihar
# 26        Junior HR Marketing manager            Kerala
# 27                       BI Developer      Uttarpradesh
# 28                    visual Designer           Gujarat
# 29  Talent Management Process Manager           Gujarat
# 30                       BI Developer               Goa
# 31  Talent Management Process Manager       Maharashtra
# 32  Talent Management Process Manager           Manipur
# 33      Lead guest Service Specialist             Assam
# 34                Bill review manager      Uttarpradesh
#
#                          department  salary_range company_profile description  \
# 7   Sales and Business Developement       32500.0              No         Yes
# 8                        Production       32500.0             Yes          No
# 9                             Sales       32500.0              No         Yes
# 10                        Financial      110000.0             Yes          No
# 11                 Playfair Capital       32500.0             Yes          No
# 12                 Playfair Capital       32500.0              No          No
# 13  Sales and Business Developement       32500.0             Yes         Yes
# 14                       ANDROIDPIT       32500.0              No          No
# 15  Sales and Business Developement      135000.0             Yes         Yes
# 16                 Playfair Capital       32500.0             Yes         Yes
# 17  Sales and Business Developement       32500.0             Yes          No
# 18                 Playfair Capital       32500.0             Yes          No
# 19                            Sales       32500.0              No         Yes
# 20                     Oil & Energy       32500.0             Yes         Yes
# 21            Business Developement       32500.0              No          No
# 22                 Playfair Capital       32500.0             Yes         Yes
# 23                     Oil & Energy      110000.0              No         Yes
# 24                       Production       32500.0              No          No
# 25                       ANDROIDPIT       32500.0              No         Yes
# 26                 Playfair Capital       32500.0              No         Yes
# 27                        Financial       32500.0              No         Yes
# 28                       Production       32500.0              No          No
# 29                       Production       32500.0             Yes         Yes
# 30            Software developement       32500.0             Yes         Yes
# 31            Software developement       57500.0              No         Yes
# 32                      Marketplace       32500.0              No         Yes
# 33            Software developement       32500.0             Yes          No
# 34            Software developement       32500.0             Yes         Yes
#
#    requirements benefits  telecommuting  has_company_logo  has_questions  \
# 7           Yes       No              0                 1              1
# 8           Yes       No              0                 1              1
# 9            No       No              0                 1              0
# 10           No       No              0                 0              0
# 11           No      Yes              0                 1              0
# 12          Yes       No              0                 1              0
# 13          Yes      Yes              0                 1              1
# 14           No       No              0                 1              0
# 15          Yes       No              0                 1              1
# 16           No      Yes              0                 1              0
# 17           No       No              0                 1              1
# 18           No      Yes              0                 1              0
# 19          Yes       No              0                 0              0
# 20           No       No              0                 1              0
# 21           No       No              0                 1              0
# 22          Yes      Yes              0                 1              1
# 23          Yes      Yes              0                 1              0
# 24           No       No              0                 0              0
# 25          Yes      Yes              0                 1              1
# 26          Yes      Yes              0                 1              0
# 27           No      Yes              0                 1              0
# 28          Yes      Yes              0                 0              0
# 29           No      Yes              0                 1              0
# 30          Yes       No              0                 1              0
# 31           No       No              0                 1              0
# 32          Yes       No              0                 1              1
# 33          Yes      Yes              0                 1              1
# 34           No       No              0                 1              1
#
#    employment_type required_experience                 required_education  \
# 7            Other         Entry level                   Associate Degree
# 8         Contract      Not Applicable  Some College Coursework Completed
# 9            Other         Entry level                        Unspecified
# 10           Other    Mid-Senior level  Some College Coursework Completed
# 11       Temporary         Entry level                          Doctorate
# 12        Contract          Internship                    master's degree
# 13           Other          Internship                        Unspecified
# 14           Other           Executive                    master's degree
# 15       Part-Time          Internship                       Professional
# 16       Temporary         Entry level                          Doctorate
# 17       Full-Time           Associate                  Bachelor's degree
# 18       Temporary            Director           Highschool or equivalant
# 19           Other            Director                       Professional
# 20       Temporary          Internship                   Associate Degree
# 21        Contract            Director                      Certification
# 22       Full-Time           Associate                   Associate Degree
# 23       Part-Time      Not Applicable                    master's degree
# 24       Part-Time    Mid-Senior level                    master's degree
# 25       Full-Time           Executive           Highschool or equivalant
# 26           Other         Entry level                    master's degree
# 27           Other         Entry level                        Unspecified
# 28       Temporary      Not Applicable                   Associate Degree
# 29       Temporary           Associate                  Bachelor's degree
# 30       Full-Time      Not Applicable                    master's degree
# 31           Other      Not Applicable                         Vocational
# 32           Other    Mid-Senior level                          Doctorate
# 33       Temporary    Mid-Senior level                      Certification
# 34           Other      Not Applicable                  Bachelor's degree
#
#                                industry                function  fraudulent
# 7                Management Counsulting          Administrative           0
# 8                  Education management        Customer Service           0
# 9   Information Technology and Services  Information Technology           0
# 10                 Consumer Electronics        Customer Service           0
# 11                    Consumer Services            Supply Chain           0
# 12                 Consumer Electronics             Engineering           0
# 13                   Telecommunications              Management           0
# 14                 Education management             Engineering           0
# 15                             Internet                   sales           0
# 16             Hospital and Health Care               Marketing           0
# 17               Management Counsulting                  Design           0
# 18                   Telecommunications                   sales           0
# 19                      Events Services    Health Care Provider           0
# 20               Management Counsulting  Information Technology           0
# 21                    Computer Software    Health Care Provider           0
# 22                 Education management            Supply Chain           0
# 23                   Telecommunications               Marketing           0
# 24                             Internet                   sales           0
# 25                        Oil & Enenrgy          Administrative           0
# 26               Management Counsulting              Management           0
# 27                         Online Media               Marketing           0
# 28                         Online Media  Information Technology           0
# 29               Management Counsulting             Engineering           0
# 30                    Computer Software              Management           0
# 31                   Financial Services              Production           0
# 32                      Events Services  Information Technology           0
# 33                   Financial Services        Customer Service           0
# 34                   Telecommunications              Management           0

# %%
data1.isnull().sum()
# Out:
# title                  0
# location               0
# department             0
# salary_range           0
# company_profile        0
# description            0
# requirements           0
# benefits               0
# telecommuting          0
# has_company_logo       0
# has_questions          0
# employment_type        0
# required_experience    0
# required_education     0
# industry               0
# function               0
# fraudulent             0
# dtype: int64

# %%
data1.title.unique()
# Out:
# array(['Bill review manager', 'Marketing Intern',
#        'Lead guest Service Specialist', 'Project manager',
#        'Junior HR Marketing manager', 'Software Application Specialist',
#        'visual Designer', 'BI Developer',
#        'Talent Management Process Manager', 'Accounting Clerk',
#        'Application Developer'], dtype=object)

# %%
le=LabelEncoder()

# %%
for i in data1:
  if data[i].dtype==np.dtype('O'):
    data1[i]=le.fit_transform(data1[i])

# %%
data1
# Out:
#      title  location  department  salary_range  company_profile  description  \
# 0        3         1           6       32500.0                1            0
# 1        6         3           1       32500.0                1            1
# 2        5         2           5       32500.0                1            1
# 3        7         6           5       32500.0                1            1
# 4        4         4           9       32500.0                0            0
# ..     ...       ...         ...           ...              ...          ...
# 515      6         0           0       32500.0                0            0
# 516      7        11           6       32500.0                1            0
# 517      9        19           7       32500.0                0            0
# 518     10        19           9       32500.0                1            1
# 519      6         0           7       32500.0                0            0
#
#      requirements  benefits  telecommuting  has_company_logo  has_questions  \
# 0               1         0              0                 1              0
# 1               0         0              0                 1              0
# 2               0         0              0                 1              0
# 3               1         0              0                 1              0
# 4               0         1              0                 1              1
# ..            ...       ...            ...               ...            ...
# 515             0         1              0                 1              1
# 516             1         1              0                 1              0
# 517             0         1              0                 1              0
# 518             0         1              0                 0              0
# 519             0         1              0                 1              1
#
#      employment_type  required_experience  required_education  industry  \
# 0                  2                    6                   6         3
# 1                  3                    5                   1        14
# 2                  1                    6                   8         3
# 3                  1                    1                   0         5
# 4                  3                    5                   9         9
# ..               ...                  ...                 ...       ...
# 515                4                    6                   2        12
# 516                4                    6                   0         4
# 517                3                    3                   2         9
# 518                1                    4                   0        11
# 519                4                    5                   4         3
#
#      function  fraudulent
# 0           1           0
# 1           0           0
# 2           4           0
# 3           5           0
# 4          10           0
# ..        ...         ...
# 515         6           0
# 516         6           0
# 517         8           0
# 518         6           0
# 519         8           0
#
# [520 rows x 17 columns]

# %%
data1['salary_range'].unique()
# Out:
# array([3.250e+04, 2.400e+04, 1.100e+05, 1.350e+05, 5.750e+04, 4.500e+04,
#        7.000e+01, 6.750e+04, 9.500e+01, 9.250e+04, 1.850e+04, 2.200e+04,
#        1.050e+05, 1.650e+04, 6.000e+04, 5.250e+04, 3.500e+04, 8.000e+04,
#        1.200e+04, 8.000e+01, 3.650e+04, 1.715e+04, 3.750e+04, 1.000e+01,
#        5.050e+04, 2.325e+04, 6.500e+04, 0.000e+00, 3.000e+04, 4.800e+05,
#        9.000e+04, 1.575e+04, 4.750e+04, 3.350e+04, 5.600e+04, 1.170e+05,
#        5.500e+04, 5.000e+02, 3.800e+04, 9.500e+04, 5.400e+04, 1.900e+04,
#        7.560e+06, 4.850e+04, 1.250e+05, 3.300e+04, 1.650e+03, 5.000e+04,
#        3.600e+04, 7.500e+01, 1.300e+04, 2.592e+04, 1.075e+02])

# %%
data1
# Out:
#      title  location  department  salary_range  company_profile  description  \
# 0        3         1           6       32500.0                1            0
# 1        6         3           1       32500.0                1            1
# 2        5         2           5       32500.0                1            1
# 3        7         6           5       32500.0                1            1
# 4        4         4           9       32500.0                0            0
# ..     ...       ...         ...           ...              ...          ...
# 515      6         0           0       32500.0                0            0
# 516      7        11           6       32500.0                1            0
# 517      9        19           7       32500.0                0            0
# 518     10        19           9       32500.0                1            1
# 519      6         0           7       32500.0                0            0
#
#      requirements  benefits  telecommuting  has_company_logo  has_questions  \
# 0               1         0              0                 1              0
# 1               0         0              0                 1              0
# 2               0         0              0                 1              0
# 3               1         0              0                 1              0
# 4               0         1              0                 1              1
# ..            ...       ...            ...               ...            ...
# 515             0         1              0                 1              1
# 516             1         1              0                 1              0
# 517             0         1              0                 1              0
# 518             0         1              0                 0              0
# 519             0         1              0                 1              1
#
#      employment_type  required_experience  required_education  industry  \
# 0                  2                    6                   6         3
# 1                  3                    5                   1        14
# 2                  1                    6                   8         3
# 3                  1                    1                   0         5
# 4                  3                    5                   9         9
# ..               ...                  ...                 ...       ...
# 515                4                    6                   2        12
# 516                4                    6                   0         4
# 517                3                    3                   2         9
# 518                1                    4                   0        11
# 519                4                    5                   4         3
#
#      function  fraudulent
# 0           1           0
# 1           0           0
# 2           4           0
# 3           5           0
# 4          10           0
# ..        ...         ...
# 515         6           0
# 516         6           0
# 517         8           0
# 518         6           0
# 519         8           0
#
# [520 rows x 17 columns]

# %%
data1.to_csv('cleaned.csv')
